# %%
import matplotlib.pyplot as plt
import numpy as np
from astropy.table import Table
import pandas as pd
import sys
import os


#from pixell import enmap, enplot

# %%
print("Current Working Directory:", os.getcwd())
print("Files in this directory:", os.listdir())
# %pwd
# Out:
# Current Working Directory: C:\Users\jonat\ULAB
# Files in this directory: ['.ipynb_checkpoints', 'DR5.fits', 'DR5_cluster-catalog_v1.1.fits (1).txt', 'Nov3rd25.ipynb', 'ULAB_HW5.ipynb', 'Untitled.ipynb', 'world_cities.csv']
# 'C:\\Users\\jonat\\ULAB'

# %%
print(sys.version)
df=Table.read('DR5_cluster-catalog_v1.1.fits (1).txt')
df
# Out:
# 3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 16:37:03) [MSC v.1929 64 bit (AMD64)]
# <Table length=4195>
#         name        ...
#       bytes19       ...
# ------------------- ...
# ACT-CL J0000.0-3837 ...
# ACT-CL J0000.2-4357 ...
# ACT-CL J0000.3-2805 ...
# ACT-CL J0000.3-3936 ...
# ACT-CL J0000.4-0102 ...
# ACT-CL J0000.4-0552 ...
# ACT-CL J0000.7+0225 ...
# ACT-CL J0000.7-5957 ...
# ACT-CL J0000.9-0712 ...
#                 ... ...
# ACT-CL J2357.9-4432 ...
# ACT-CL J2358.1+1934 ...
# ACT-CL J2358.5-1307 ...
# ACT-CL J2358.7-4129 ...
# ACT-CL J2358.8+1836 ...
# ACT-CL J2358.9-4354 ...
# ACT-CL J2359.5+0208 ...
# ACT-CL J2359.5-4608 ...
# ACT-CL J2359.7-5010 ...
# ACT-CL J2359.9-3256 ...
